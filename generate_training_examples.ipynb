# %%
import numpy as np
import tensorflow as tf
import librosa
import os
import soundfile as sf
import numpy as np
import data
import pywt
import cv2
from data import WaveData

# %%
from data import SR

PATH = 'data/medley_processed/V2/'

# Split into 10s chunks & (TODO:) add overlap if we want to do for more examples

def split_audios(stem, duration=10):

    #Load in stems
    stem_audio, sr = librosa.load(stem, mono=False, sr=SR)

    # Transpose to have time as first dimension
    stem_audio = stem_audio.T

    # get total number of samples and number of chunks
    n_samples = len(stem_audio)
    print(n_samples)
    n_chunks = n_samples // (sr * duration)
    print(n_chunks)
    chunks = []

    # Split into chunks
    for i in range(n_chunks):
        start = i * sr * duration
        end = (i + 1) * sr * duration
        stem_chunk = stem_audio[start:end]
        chunks.append(stem_chunk)

    return chunks


def write_audio(chunks, stemname, destination=PATH):

    # Create directory for trainin

    for i, chunk in enumerate(chunks):
        
        sf.write(f'{destination}{stemname}_{i}.wav', chunk, SR)

# %%
def split_per_folder(folder):
    # Get all stems in folder
    if not os.path.isdir(PATH + folder):
        print(f"Folder {folder} does not exist. Skipping.")
        return None
    os.makedirs(PATH + folder + "/vox_training", exist_ok=True)
    os.makedirs(PATH + folder + "/vox_true", exist_ok=True)
    stem_folders = os.listdir(PATH + folder)
    stem_folders = [folder + '/' + stem_folder for stem_folder in stem_folders if "SUM" in stem_folder and "vocals" in stem_folder]
    vox_stems = [folder + '/' + stem for stem in os.listdir(PATH + folder) if stem=="vocals_INSTR"]
    if len(vox_stems) == 0:
        print("No vocals found for this folder. Skipping.", folder)
        return None
    else:
        print(f"Processing {folder}")
        print(f"Vocals found: {vox_stems[0]}")
    vox_split = split_audios(PATH + vox_stems[0] +"/vocals_INSTR_SUM.wav")
    print(len(vox_split))

    ## write vox stem
    write_audio(vox_split, "vocals", PATH + folder + "/vox_true")
    
    for i, stem in enumerate(stem_folders):
        print(f"Processing stem: {stem}")
        file = os.listdir(PATH + stem)[0]
        print(file)
        chunks = split_audios(PATH + stem + "/" + file)
        # print(chunks)
        write_audio(chunks, i, PATH + folder + "/vox_training")

def main():
    folders = os.listdir(PATH)
    for i, folder in enumerate(folders):
        split_per_folder(folder)

# %%
main()
# Out:
# No vocals found for this folder. Skipping. RodrigoBonelli_BalladForLaura
# Processing MidnightBlue_StarsAreScreaming
# Vocals found: MidnightBlue_StarsAreScreaming/vocals_INSTR
# 12030951
# 27
# 27
# Processing stem: MidnightBlue_StarsAreScreaming/MidnightBlue_StarsAreScreaming_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# MidnightBlue_StarsAreScreaming_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 12030951
# 27
# Processing stem: MidnightBlue_StarsAreScreaming/MidnightBlue_StarsAreScreaming_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# MidnightBlue_StarsAreScreaming_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 12030951
# 27
# Processing stem: MidnightBlue_StarsAreScreaming/MidnightBlue_StarsAreScreaming_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# MidnightBlue_StarsAreScreaming_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 12030951
# 27
# Processing stem: MidnightBlue_StarsAreScreaming/MidnightBlue_StarsAreScreaming_electricbass_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# MidnightBlue_StarsAreScreaming_electricbass_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 12030951
# 27
# Processing stem: MidnightBlue_StarsAreScreaming/MidnightBlue_StarsAreScreaming_vocals_INSTR_SUM_drumset_INSTR_SUM
# MidnightBlue_StarsAreScreaming_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 12030951
# 27
# Processing stem: MidnightBlue_StarsAreScreaming/MidnightBlue_StarsAreScreaming_electricbass_INSTR_SUM_vocals_INSTR_SUM
# MidnightBlue_StarsAreScreaming_electricbass_INSTR_SUM_vocals_INSTR_SUM.wav
# 12030951
# 27
# No vocals found for this folder. Skipping. SasquatchConnection_HolyClamsBatman
# No vocals found for this folder. Skipping. DeclareAString_MendelssohnPianoTrio1Movement2
# No vocals found for this folder. Skipping. HopsNVinyl_ReignCheck
# No vocals found for this folder. Skipping. AmadeusRedux_SchubertMovement3
# Folder AClassicEducation_NightOwl_METADATA.yaml does not exist. Skipping.
# Processing CassandraJenkins_PerfectDay
# Vocals found: CassandraJenkins_PerfectDay/vocals_INSTR
# 11256766
# 25
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_stringsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_stringsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_synthesizer_INSTR_SUM_stringsection_INSTR_SUM_hornsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# Processing stem: CassandraJenkins_PerfectDay/CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# CassandraJenkins_PerfectDay_electricbass_INSTR_SUM_synthesizer_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11256766
# 25
# No vocals found for this folder. Skipping. AmadeusRedux_SchubertMovement2
# Processing DahkaBand_SoldierMan
# Vocals found: DahkaBand_SoldierMan/vocals_INSTR
# 14505845
# 32
# 32
# Processing stem: DahkaBand_SoldierMan/DahkaBand_SoldierMan_tenorsaxophone_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# DahkaBand_SoldierMan_tenorsaxophone_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 14505845
# 32
# Processing stem: DahkaBand_SoldierMan/DahkaBand_SoldierMan_doublebass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# DahkaBand_SoldierMan_doublebass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 14505845
# 32
# Processing stem: DahkaBand_SoldierMan/DahkaBand_SoldierMan_doublebass_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# DahkaBand_SoldierMan_doublebass_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 14505845
# 32
# Processing stem: DahkaBand_SoldierMan/DahkaBand_SoldierMan_doublebass_INSTR_SUM_tenorsaxophone_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# DahkaBand_SoldierMan_doublebass_INSTR_SUM_tenorsaxophone_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 14505845
# 32
# Processing stem: DahkaBand_SoldierMan/DahkaBand_SoldierMan_doublebass_INSTR_SUM_tenorsaxophone_INSTR_SUM_vocals_INSTR_SUM
# DahkaBand_SoldierMan_doublebass_INSTR_SUM_tenorsaxophone_INSTR_SUM_vocals_INSTR_SUM.wav
# 14505845
# 32
# Processing stem: DahkaBand_SoldierMan/DahkaBand_SoldierMan_tenorsaxophone_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# DahkaBand_SoldierMan_tenorsaxophone_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 14505845
# 32
# Processing stem: DahkaBand_SoldierMan/DahkaBand_SoldierMan_tenorsaxophone_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# DahkaBand_SoldierMan_tenorsaxophone_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 14505845
# 32
# Processing stem: DahkaBand_SoldierMan/DahkaBand_SoldierMan_doublebass_INSTR_SUM_tenorsaxophone_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# DahkaBand_SoldierMan_doublebass_INSTR_SUM_tenorsaxophone_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 14505845
# 32
# Processing stem: DahkaBand_SoldierMan/DahkaBand_SoldierMan_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# DahkaBand_SoldierMan_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 14505845
# 32
# Processing stem: DahkaBand_SoldierMan/DahkaBand_SoldierMan_doublebass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# DahkaBand_SoldierMan_doublebass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 14505845
# 32
# Processing Verdi_IlTrovatore
# Vocals found: Verdi_IlTrovatore/vocals_INSTR
# 15243482
# 34
# 34
# No vocals found for this folder. Skipping. TemperedElan_WiseOne
# Folder .DS_Store does not exist. Skipping.
# No vocals found for this folder. Skipping. AmadeusRedux_MozartAllegro
# No vocals found for this folder. Skipping. MatthewEntwistle_ReturnToVenezia
# No vocals found for this folder. Skipping. TheNoHoStringOrchestra_ElgarMovement2
# No vocals found for this folder. Skipping. FennelCartwright_FlowerDrumSong
# No vocals found for this folder. Skipping. HopsNVinyl_WidowsWalk
# Processing TheTonTons_Lush
# Vocals found: TheTonTons_Lush/vocals_INSTR
# 9478144
# 21
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheTonTons_Lush_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheTonTons_Lush_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# TheTonTons_Lush_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheTonTons_Lush_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_tambourine_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheTonTons_Lush_tambourine_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheTonTons_Lush_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheTonTons_Lush_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# TheTonTons_Lush_tambourine_INSTR_SUM_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# TheTonTons_Lush_electricbass_INSTR_SUM_tambourine_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 9478144
# 21
# Processing stem: TheTonTons_Lush/TheTonTons_Lush_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheTonTons_Lush_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 9478144
# 21
# No vocals found for this folder. Skipping. Karachacha_Volamos
# No vocals found for this folder. Skipping. FallingSparks_PakKlongTalad
# No vocals found for this folder. Skipping. TheFranckDuo_FranckViolinSonataInAMajorMovement2
# No vocals found for this folder. Skipping. TheNoHoStringOrchestra_ElgarMovement3
# No vocals found for this folder. Skipping. SasquatchConnection_ThanksALatte
# No vocals found for this folder. Skipping. Katzn_CharlieKnox
# No vocals found for this folder. Skipping. PoliceHearingDepartment_VivaldiMovement1
# No vocals found for this folder. Skipping. SlowGhost_YoureAMystery
# Processing BarefootSisters_RedJetta
# Vocals found: BarefootSisters_RedJetta/vocals_INSTR
# 11900235
# 26
# 26
# Processing stem: BarefootSisters_RedJetta/BarefootSisters_RedJetta_piano_INSTR_SUM_vocals_INSTR_SUM
# BarefootSisters_RedJetta_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 11900235
# 26
# Processing stem: BarefootSisters_RedJetta/BarefootSisters_RedJetta_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# BarefootSisters_RedJetta_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 11900235
# 26
# Processing stem: BarefootSisters_RedJetta/BarefootSisters_RedJetta_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# BarefootSisters_RedJetta_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 11900235
# 26
# Processing stem: BarefootSisters_RedJetta/BarefootSisters_RedJetta_vocals_INSTR_SUM_drumset_INSTR_SUM
# BarefootSisters_RedJetta_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 11900235
# 26
# Processing stem: BarefootSisters_RedJetta/BarefootSisters_RedJetta_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# BarefootSisters_RedJetta_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 11900235
# 26
# Processing stem: BarefootSisters_RedJetta/BarefootSisters_RedJetta_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# BarefootSisters_RedJetta_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 11900235
# 26
# No vocals found for this folder. Skipping. HopsNVinyl_HoneyBrown
# No vocals found for this folder. Skipping. FennelCartwright_WinterLake
# No vocals found for this folder. Skipping. SasquatchConnection_Struttin
# No vocals found for this folder. Skipping. FallingSparks_Improvisation3
# No vocals found for this folder. Skipping. SlowGhost_FirstSnow
# Processing TheKitchenettes_Alive
# Vocals found: TheKitchenettes_Alive/vocals_INSTR
# 10039063
# 22
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# TheKitchenettes_Alive_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 10039063
# 22
# Processing stem: TheKitchenettes_Alive/TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# TheKitchenettes_Alive_electricbass_INSTR_SUM_violin_INSTR_SUM_cleanelectricguitar_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 10039063
# 22
# No vocals found for this folder. Skipping. SlowGhost_MidnightGroove
# No vocals found for this folder. Skipping. PoliceHearingDepartment_SchumannMovement1
# Processing TleilaxEnsemble_Late
# Vocals found: TleilaxEnsemble_Late/vocals_INSTR
# 2160900
# 4
# 4
# Processing stem: TleilaxEnsemble_Late/TleilaxEnsemble_Late_violin_INSTR_SUM_MainSystem_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_Late_violin_INSTR_SUM_MainSystem_INSTR_SUM_vocals_INSTR_SUM.wav
# 2160900
# 4
# Processing stem: TleilaxEnsemble_Late/TleilaxEnsemble_Late_violin_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_Late_violin_INSTR_SUM_vocals_INSTR_SUM.wav
# 2160900
# 4
# Processing stem: TleilaxEnsemble_Late/TleilaxEnsemble_Late_doublebass_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_Late_doublebass_INSTR_SUM_vocals_INSTR_SUM.wav
# 2160900
# 4
# Processing stem: TleilaxEnsemble_Late/TleilaxEnsemble_Late_doublebass_INSTR_SUM_MainSystem_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_Late_doublebass_INSTR_SUM_MainSystem_INSTR_SUM_vocals_INSTR_SUM.wav
# 2160900
# 4
# Processing stem: TleilaxEnsemble_Late/TleilaxEnsemble_Late_doublebass_INSTR_SUM_violin_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_Late_doublebass_INSTR_SUM_violin_INSTR_SUM_vocals_INSTR_SUM.wav
# 2160900
# 4
# Processing stem: TleilaxEnsemble_Late/TleilaxEnsemble_Late_MainSystem_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_Late_MainSystem_INSTR_SUM_vocals_INSTR_SUM.wav
# 2160900
# 4
# Processing QuantumChromos_Circuits
# Vocals found: QuantumChromos_Circuits/vocals_INSTR
# 9699328
# 21
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_bassdrum_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_bassdrum_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_clarinet_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_clarinet_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_violin_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_violin_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_clarinet_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_violin_INSTR_SUM_bassdrum_INSTR_SUM_MainSystem_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_bassdrum_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_MainSystem_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_doublebass_INSTR_SUM_violin_INSTR_SUM_MainSystem_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# Processing stem: QuantumChromos_Circuits/QuantumChromos_Circuits_violin_INSTR_SUM_bassdrum_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# QuantumChromos_Circuits_violin_INSTR_SUM_bassdrum_INSTR_SUM_clarinet_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 9699328
# 21
# No vocals found for this folder. Skipping. FallingSparks_Improvisation2
# No vocals found for this folder. Skipping. Sweat_Tact
# No vocals found for this folder. Skipping. DeclareAString_MendelssohnPianoTrio1Movement1
# No vocals found for this folder. Skipping. Sweat_Sn1572
# Processing MutualBenefit_NotForNothing
# Vocals found: MutualBenefit_NotForNothing/vocals_INSTR
# 7956480
# 18
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# MutualBenefit_NotForNothing_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_violin_INSTR_SUM_violinsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_violin_INSTR_SUM_violinsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_violin_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violinsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violinsection_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_violin_INSTR_SUM_violinsection_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_violin_INSTR_SUM_violinsection_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing stem: MutualBenefit_NotForNothing/MutualBenefit_NotForNothing_electricbass_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# MutualBenefit_NotForNothing_electricbass_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 7956480
# 18
# Processing PeterMatthewBauer_YouAlwaysLookForSomeoneLost
# Vocals found: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/vocals_INSTR
# 16724311
# 37
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 16724311
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 16724311
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_piano_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_piano_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 16724311
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_piano_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_piano_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 16724311
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 16724311
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_piano_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_piano_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 16724311
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_piano_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_piano_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 16724311
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 16724311
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_piano_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 16724311
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# PeterMatthewBauer_YouAlwaysLookForSomeoneLost_electricbass_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 16724311
# 37
# Processing stem: PeterMatthewBauer_YouAlwaysLookForSomeoneLost/PeterMatthewBauer_YouAlwaysLookForSomeoneLost_piano_INSTR_SUM_auxiliarypercussion_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# ...
# LittleTybee_TheAlchemist_electricbass_INSTR_SUM_electricpiano_INSTR_SUM_violin_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 8880128
# 20
# Processing stem: LittleTybee_TheAlchemist/LittleTybee_TheAlchemist_electricbass_INSTR_SUM_electricpiano_INSTR_SUM_violin_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# LittleTybee_TheAlchemist_electricbass_INSTR_SUM_electricpiano_INSTR_SUM_violin_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 8880128
# 20
# Processing PatternIsMovement_SaveMe
# Vocals found: PatternIsMovement_SaveMe/vocals_INSTR
# 11853824
# 26
# 26
# Processing stem: PatternIsMovement_SaveMe/PatternIsMovement_SaveMe_electronicorgan_INSTR_SUM_vocals_INSTR_SUM
# PatternIsMovement_SaveMe_electronicorgan_INSTR_SUM_vocals_INSTR_SUM.wav
# 11853824
# 26
# Processing stem: PatternIsMovement_SaveMe/PatternIsMovement_SaveMe_vocals_INSTR_SUM_drumset_INSTR_SUM
# PatternIsMovement_SaveMe_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 11853824
# 26
# Processing SongYiJeon_TwoMoons
# Vocals found: SongYiJeon_TwoMoons/vocals_INSTR
# 14617328
# 33
# 33
# Processing CatMartino_IPromise
# Vocals found: CatMartino_IPromise/vocals_INSTR
# 24340559
# 55
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM
# CatMartino_IPromise_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CatMartino_IPromise_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_synthesizer_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CatMartino_IPromise_synthesizer_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM
# CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CatMartino_IPromise_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CatMartino_IPromise_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM
# CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_synthesizer_INSTR_SUM_fx_processedsound_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CatMartino_IPromise_synthesizer_INSTR_SUM_fx_processedsound_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_vocals_INSTR_SUM
# CatMartino_IPromise_synthesizer_INSTR_SUM_electronicorgan_INSTR_SUM_fx_processedsound_INSTR_SUM_vocals_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_synthesizer_INSTR_SUM_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM
# CatMartino_IPromise_synthesizer_INSTR_SUM_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_synthesizer_INSTR_SUM_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CatMartino_IPromise_synthesizer_INSTR_SUM_fx_processedsound_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 24340559
# 55
# Processing stem: CatMartino_IPromise/CatMartino_IPromise_electronicorgan_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# CatMartino_IPromise_electronicorgan_INSTR_SUM_drummachine_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 24340559
# 55
# No vocals found for this folder. Skipping. SasquatchConnection_Illuminati
# Processing TleilaxEnsemble_MelancholyFlowers
# Vocals found: TleilaxEnsemble_MelancholyFlowers/vocals_INSTR
# 4057200
# 9
# 9
# Processing stem: TleilaxEnsemble_MelancholyFlowers/TleilaxEnsemble_MelancholyFlowers_doublebass_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_MelancholyFlowers_doublebass_INSTR_SUM_vocals_INSTR_SUM.wav
# 4057200
# 9
# Processing stem: TleilaxEnsemble_MelancholyFlowers/TleilaxEnsemble_MelancholyFlowers_violin_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_MelancholyFlowers_violin_INSTR_SUM_vocals_INSTR_SUM.wav
# 4057200
# 9
# Processing stem: TleilaxEnsemble_MelancholyFlowers/TleilaxEnsemble_MelancholyFlowers_violin_INSTR_SUM_MainSystem_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_MelancholyFlowers_violin_INSTR_SUM_MainSystem_INSTR_SUM_vocals_INSTR_SUM.wav
# 4057200
# 9
# Processing stem: TleilaxEnsemble_MelancholyFlowers/TleilaxEnsemble_MelancholyFlowers_doublebass_INSTR_SUM_violin_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_MelancholyFlowers_doublebass_INSTR_SUM_violin_INSTR_SUM_vocals_INSTR_SUM.wav
# 4057200
# 9
# Processing stem: TleilaxEnsemble_MelancholyFlowers/TleilaxEnsemble_MelancholyFlowers_doublebass_INSTR_SUM_MainSystem_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_MelancholyFlowers_doublebass_INSTR_SUM_MainSystem_INSTR_SUM_vocals_INSTR_SUM.wav
# 4057200
# 9
# Processing stem: TleilaxEnsemble_MelancholyFlowers/TleilaxEnsemble_MelancholyFlowers_MainSystem_INSTR_SUM_vocals_INSTR_SUM
# TleilaxEnsemble_MelancholyFlowers_MainSystem_INSTR_SUM_vocals_INSTR_SUM.wav
# 4057200
# 9
# No vocals found for this folder. Skipping. PoliceHearingDepartment_Brahms
# No vocals found for this folder. Skipping. PoliceHearingDepartment_SchumannMovement2
# No vocals found for this folder. Skipping. HopsNVinyl_ChickenFriedSteak
# No vocals found for this folder. Skipping. FennelCartwright_DearTessie
# Processing Cayetana_MissThing
# Vocals found: Cayetana_MissThing/vocals_INSTR
# 10452992
# 23
# 23
# Processing stem: Cayetana_MissThing/Cayetana_MissThing_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# Cayetana_MissThing_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 10452992
# 23
# Processing stem: Cayetana_MissThing/Cayetana_MissThing_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# Cayetana_MissThing_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 10452992
# 23
# Processing stem: Cayetana_MissThing/Cayetana_MissThing_vocals_INSTR_SUM_drumset_INSTR_SUM
# Cayetana_MissThing_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 10452992
# 23
# Processing stem: Cayetana_MissThing/Cayetana_MissThing_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# Cayetana_MissThing_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 10452992
# 23
# Processing stem: Cayetana_MissThing/Cayetana_MissThing_electricbass_INSTR_SUM_vocals_INSTR_SUM
# Cayetana_MissThing_electricbass_INSTR_SUM_vocals_INSTR_SUM.wav
# 10452992
# 23
# Processing stem: Cayetana_MissThing/Cayetana_MissThing_electricbass_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# Cayetana_MissThing_electricbass_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 10452992
# 23
# Processing DeadMilkmen_PrisonersCinema
# Vocals found: DeadMilkmen_PrisonersCinema/vocals_INSTR
# 9961472
# 22
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_electronicorgan_INSTR_SUM_vocals_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_electronicorgan_INSTR_SUM_vocals_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_glockenspiel_INSTR_SUM_vocals_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_glockenspiel_INSTR_SUM_vocals_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_tambourine_INSTR_SUM_vocals_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_tambourine_INSTR_SUM_vocals_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_electricbass_INSTR_SUM_vocals_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_electricbass_INSTR_SUM_vocals_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_fx_processedsound_INSTR_SUM_vocals_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_fx_processedsound_INSTR_SUM_vocals_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_vocals_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_vocals_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_castanet_INSTR_SUM_vocals_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_castanet_INSTR_SUM_vocals_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_cleanelectricguitar_INSTR_SUM_vocals_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_shaker_INSTR_SUM_vocals_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_shaker_INSTR_SUM_vocals_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing stem: DeadMilkmen_PrisonersCinema/DeadMilkmen_PrisonersCinema_vocals_INSTR_SUM_drumset_INSTR_SUM_EXCL
# DeadMilkmen_PrisonersCinema_vocals_INSTR_SUM_drumset_INSTR_SUM_EXCL.wav
# 9961472
# 22
# Processing FruitCathedral_KeepMeRunnin
# Vocals found: FruitCathedral_KeepMeRunnin/vocals_INSTR
# 13005176
# 29
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_shaker_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# FruitCathedral_KeepMeRunnin_shaker_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# FruitCathedral_KeepMeRunnin_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM
# FruitCathedral_KeepMeRunnin_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM
# FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM
# FruitCathedral_KeepMeRunnin_electricbass_INSTR_SUM_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_drumset_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# FruitCathedral_KeepMeRunnin_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 13005176
# 29
# Processing stem: FruitCathedral_KeepMeRunnin/FruitCathedral_KeepMeRunnin_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM
# FruitCathedral_KeepMeRunnin_shaker_INSTR_SUM_distortedelectricguitar_INSTR_SUM_vocals_INSTR_SUM_acousticguitar_INSTR_SUM_drumset_INSTR_SUM.wav
# 13005176
# 29
# No vocals found for this folder. Skipping. FallingSparks_Improvisation1
# No vocals found for this folder. Skipping. Sweat_Elegy

# %%
for folder in os.listdir(PATH):
    if not os.path.isdir(PATH + folder):
        continue
    files = os.listdir(PATH + folder )
    files = [file for file in files if "vox_training" in file and "wav" in file]
    #move to /vox_training
    for file in files:
        os.rename(PATH + folder + "/" + file, PATH + folder+ "/vox_training/" + file)
    files = os.listdir(PATH + folder )
    files = [file for file in files if "vox_true" in file and "wav" in file]
    # remove
    for file in files:
        os.remove(PATH + folder + "/" + file)

# %%
# make dict for training of all files that have vox_training
files_dict = {}

for folder in os.listdir(PATH):
    if not os.path.isdir(PATH + folder):
        continue
    files = os.listdir(PATH + folder )
    if "vox_training" in files and len(os.listdir(PATH + folder + "/vox_training")) > 0:
        files = [file for file in files if "vox_training" in file and "wav" in file]
        files_dict[folder] = files

# %%
print(files_dict.keys())
# Out:
# dict_keys(['MidnightBlue_StarsAreScreaming', 'CassandraJenkins_PerfectDay', 'DahkaBand_SoldierMan', 'TheTonTons_Lush', 'BarefootSisters_RedJetta', 'TheKitchenettes_Alive', 'TleilaxEnsemble_Late', 'QuantumChromos_Circuits', 'MutualBenefit_NotForNothing', 'PeterMatthewBauer_YouAlwaysLookForSomeoneLost', 'LewisAndClarke_TheSilverSea', 'Torres_NewSkin', 'MidnightBlue_HuntingSeason', 'TrevorAndTheSoundwaves_AloneAndSad', 'FilthyBird_IdLikeToKnow', 'LittleTybee_TheAlchemist', 'PatternIsMovement_SaveMe', 'CatMartino_IPromise', 'TleilaxEnsemble_MelancholyFlowers', 'Cayetana_MissThing', 'DeadMilkmen_PrisonersCinema', 'FruitCathedral_KeepMeRunnin'])

# %%
test_song_name = 'MidnightBlue_StarsAreScreaming'


def getWaveletTransform(data, song, level=12):
    if data[song].waveform.shape[0] == 2:
        data[song].waveform = np.transpose(data[song].waveform)
    print(f"Left channel waveform: {data[song].waveform[:, 0]}")
    # Perform wavelet decomposition
    coeffs_left = pywt.wavedec(data[song].waveform[:, 0], 'db1', level=level)
    coeffs_right = pywt.wavedec(data[song].waveform[:, 1], 'db1', level=level)
    print(f"Left coefficients shape: {[c.shape for c in coeffs_left]}")

    # Find the maximum length among all coefficients
    max_len = max([c.shape[0] for c in coeffs_left + coeffs_right])

    # Stretch the coefficients to the maximum length using interpolation
    stretched_coeffs_left = []
    stretched_coeffs_right = []
    for c_left, c_right in zip(coeffs_left, coeffs_right):
        stretched_left = cv2.resize(c_left.reshape(1, -1), (max_len, 1), interpolation=cv2.INTER_NEAREST).flatten()
        stretched_right = cv2.resize(c_right.reshape(1, -1), (max_len, 1), interpolation=cv2.INTER_NEAREST).flatten()
        stretched_coeffs_left.append(stretched_left)
        stretched_coeffs_right.append(stretched_right)

    # Stack the stretched coefficients along the channel axis
    stacked_coeffs = np.stack([stretched_coeffs_left, stretched_coeffs_right], axis=-1)

    # Convert the stacked coefficients to a TensorFlow tensor
    tensor_coeffs = tf.convert_to_tensor(stacked_coeffs)
    print(f"Tensor coefficients shape: {tensor_coeffs.shape}")

    data[song].dwt = coeffs_left
    data[song].tensor_coeffs = tensor_coeffs


    return data

def makeWaveDict(folder_name):
    data = {}
    filenames = os.listdir(folder_name)
    filenames = [folder_name + filename for filename in filenames if filename.endswith('.wav')]
    for filename in filenames:
        print(f"Loading {filename}")
        waveform, _ =librosa.load(filename, sr=SR, mono=False)
        print(f"Waveform shape: {waveform.shape}")
        np.transpose(waveform)
        data[filename] = WaveData(filename, waveform, None)
    return data

TEST_SONG_PATH_TRAINING = PATH + test_song_name + "/vox_training/"
TEST_SONG_PATH_TRUE = PATH + test_song_name + "/vox_true/"
assert os.path.isdir(TEST_SONG_PATH_TRAINING)
assert os.path.isdir(TEST_SONG_PATH_TRUE)


train_dict = makeWaveDict(TEST_SONG_PATH_TRAINING)
true_dict = makeWaveDict(TEST_SONG_PATH_TRUE)

def make_test_set(train_dict, true_dict, level=12):
    
    # for each file in train_dict, get the corresponding file in true_dict (ends with same last number + .wav)
    # call get_wavelet_transform on both dicts, and then use the WaveData.tensor_coeffs to make a test set
    # return test set

    y_train = []
    y_true = []
    for key in train_dict.keys():
        train = train_dict[key]
        index = int(key.split("_")[-1][0])
        assert int(index) >= 0
        assert index != ""
        true_key = f"vocals_{index}_pred.wav"
        true_key = TEST_SONG_PATH_TRUE + true_key
        print(true_key)
        getWaveletTransform(train_dict, key, level)
        getWaveletTransform(true_dict, true_key, level)
        true = true_dict[true_key]
        train_tensor = train.tensor_coeffs
        true_tensor = true.tensor_coeffs
        y_train.append(train_tensor)
        y_true.append(true_tensor)

    return y_train, y_true

y_train, y_true = make_test_set(train_dict, true_dict, level=5)
print(y_train[0])



# make test set
# Out:
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_1.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_16.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_23.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_3.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_26.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_5.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_4.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_2.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_22.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_17.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_0.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_2.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_15.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_20.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_0.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_19.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_25.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_6.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_7.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_24.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_18.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_1.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_21.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_14.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_3.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_7.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_25.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_10.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_19.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_5.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_20.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_3.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_2.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_21.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_4.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_11.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_18.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_24.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_6.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_4.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_26.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_13.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_6.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_23.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_0.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_1.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_22.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_7.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_12.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_5.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_11.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_6.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_0.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_14.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_21.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_2.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_3.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_20.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_15.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_1.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_7.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_10.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_12.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_5.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_3.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_17.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_22.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_1.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_0.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_23.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_16.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_2.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_4.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_13.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_17.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_0.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_6.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_12.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_4.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_5.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_13.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_26.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_7.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_1.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_16.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_14.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_3.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_5.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_24.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_11.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_18.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_7.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_6.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_10.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_19.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_25.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_4.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_2.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_15.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_24.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_18.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_9.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_21.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_14.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_15.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_20.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_8.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_19.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_25.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_22.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_17.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_8.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_9.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_16.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_23.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_26.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_22.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_9.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_12.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_26.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_13.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_8.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_23.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_21.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_11.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_18.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_24.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_25.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training5_10.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_19.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_20.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_8.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_23.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_16.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_13.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_12.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_17.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_22.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training0_9.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_20.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_15.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_9.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_10.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_11.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training2_8.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_14.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_21.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_10.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_19.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_25.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_15.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_14.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_24.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_11.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_18.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_13.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_26.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_16.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_9.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training4_8.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training1_17.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_training/vox_training3_12.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_25_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_24_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_7_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_6_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_11_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_10_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_22_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_23_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_0_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_16_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_17_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_4_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_5_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_12_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_13_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_26_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_18_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_19_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_3_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_15_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_14_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_21_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_20_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_9_pred.wav
# Waveform shape: (2, 441000)
# Loading data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_8_pred.wav
# Waveform shape: (2, 441000)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.05038452 -0.03756714 -0.02816772 ... -0.0798645  -0.09225464
#  -0.07815552]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [0.0345459  0.03805542 0.04959106 ... 0.3355713  0.26635742 0.19741821]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [ 0.00778198  0.00518799  0.0118103  ... -0.32489014 -0.29956055
#  -0.27212524]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_3_pred.wav
# Left channel waveform: [ 0.00424194 -0.00567627 -0.01312256 ...  0.0043335  -0.01062012
#  -0.01568604]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 0.00036621  0.00030518  0.00024414 ... -0.01092529 -0.0295105
#  -0.03167725]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.45977783 -0.54000854 -0.59921265 ...  0.12612915  0.11679077
#   0.11611938]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_5_pred.wav
# Left channel waveform: [-0.00588989  0.00430298  0.00952148 ... -0.10281372  0.00027466
#   0.08380127]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 0.00820923  0.01409912  0.01919556 ... -0.0531311   0.04434204
#   0.12237549]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_4_pred.wav
# Left channel waveform: [-0.01580811 -0.02182007 -0.01882935 ... -0.03173828 -0.02468872
#  -0.01803589]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-0.01797485 -0.02026367 -0.01577759 ... -0.00473022  0.
#   0.00320435]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.06414795 -0.05795288 -0.05532837 ...  0.01306152  0.0168457
#   0.01309204]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [ 0.02490234 -0.00308228  0.00723267 ...  0.01968384  0.01556396
#   0.01348877]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [ 0.12670898  0.06005859 -0.00735474 ... -0.03250122 -0.03570557
#  -0.02355957]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_0_pred.wav
# Left channel waveform: [-0.00201416 -0.00375366 -0.00549316 ... -0.05419922 -0.05349731
#  -0.04718018]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 3.0517578e-05 -3.0517578e-05 -9.1552734e-05 ...  3.0517578e-05
#  -9.1552734e-05 -2.4414062e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.04879761 -0.04595947 -0.05099487 ...  0.02420044  0.01400757
#   0.0045166 ]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [0.06149292 0.0319519  0.01748657 ... 0.00045776 0.02062988 0.03109741]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [0.09884644 0.08920288 0.08706665 ... 0.04821777 0.05960083 0.07427979]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_0_pred.wav
# Left channel waveform: [-0.00170898 -0.003479   -0.00509644 ... -0.05023193 -0.05145264
#  -0.04931641]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 3.0517578e-05 -3.0517578e-05 -9.1552734e-05 ...  3.0517578e-05
#  -9.1552734e-05 -2.4414062e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.00387573 -0.05361938 -0.11322021 ...  0.12731934  0.11532593
#   0.10357666]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [ 0.19082642  0.17816162  0.1625061  ... -0.17053223 -0.26815796
#  -0.365448  ]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_6_pred.wav
# Left channel waveform: [0.14001465 0.17932129 0.20788574 ... 0.22869873 0.23449707 0.2227478 ]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [0.17852783 0.22406006 0.25836182 ... 0.2000122  0.20635986 0.19903564]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_7_pred.wav
# Left channel waveform: [0.20568848 0.2112732  0.19317627 ... 0.0977478  0.06591797 0.03112793]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [0.1875     0.17834473 0.16720581 ... 0.0954895  0.06451416 0.02694702]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.23031616 -0.26452637 -0.28326416 ...  0.1003418   0.14004517
#   0.17019653]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.04974365 -0.04986572 -0.04629517 ...  0.0987854   0.0715332
#   0.03979492]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.04452515 -0.03909302 -0.03436279 ... -0.07717896 -0.0786438
#  -0.07244873]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [ 0.06463623  0.05944824  0.05340576 ... -0.00164795  0.00799561
#  -0.00442505]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.07479858 -0.09393311 -0.11486816 ...  0.0617981   0.04483032
#   0.04934692]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_3_pred.wav
# Left channel waveform: [-0.00250244 -0.01535034 -0.02398682 ...  0.0163269  -0.00177002
#  -0.00973511]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 0.00036621  0.00030518  0.00024414 ... -0.01092529 -0.0295105
#  -0.03167725]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_7_pred.wav
# Left channel waveform: [0.20513916 0.20059204 0.17434692 ... 0.0866394  0.06347656 0.04058838]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [0.1875     0.17834473 0.16720581 ... 0.0954895  0.06451416 0.02694702]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [ 0.18310547  0.22479248  0.22167969 ... -0.36761475 -0.4296875
#  -0.48510742]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.02987671 -0.02148438  0.00054932 ... -0.00854492 -0.00057983
#   0.00570679]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.08401489 -0.11404419 -0.1368103  ...  0.1000061   0.11364746
#   0.11334229]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_5_pred.wav
# Left channel waveform: [-0.00588989  0.00579834  0.02377319 ... -0.03729248  0.04382324
#   0.1060791 ]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 0.00820923  0.01409912  0.01919556 ... -0.0531311   0.04434204
#   0.12237549]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [0.09899902 0.10583496 0.12475586 ... 0.41656494 0.3908081  0.32943726]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_3_pred.wav
# Left channel waveform: [-0.00637817 -0.0093689  -0.01062012 ...  0.00106812 -0.0206604
#  -0.02572632]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 0.00036621  0.00030518  0.00024414 ... -0.01092529 -0.0295105
#  -0.03167725]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [ 0.01528931  0.01202393  0.00436401 ...  0.01126099 -0.00283813
#  -0.00842285]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [ 0.25906372  0.20858765  0.1836853  ... -0.00274658  0.04168701
#   0.06686401]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_4_pred.wav
# Left channel waveform: [-0.00982666 -0.02151489 -0.02316284 ...  0.00411987 -0.00241089
#  -0.00827026]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-0.01797485 -0.02026367 -0.01577759 ... -0.00473022  0.
#   0.00320435]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [ 0.00921631  0.00897217  0.01596069 ... -0.16644287 -0.1288147
#  -0.08306885]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.01290894 -0.01177979 -0.01080322 ...  0.01516724 -0.01016235
#  -0.04238892]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.2515869  -0.24224854 -0.23104858 ...  0.13442993  0.16409302
#   0.11679077]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_6_pred.wav
# Left channel waveform: [0.10723877 0.12734985 0.13232422 ... 0.23782349 0.2460022  0.23059082]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [0.17852783 0.22406006 0.25836182 ... 0.2000122  0.20635986 0.19903564]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_4_pred.wav
# Left channel waveform: [-0.00765991 -0.02307129 -0.0262146  ... -0.02288818 -0.02709961
#  -0.0295105 ]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-0.01797485 -0.02026367 -0.01577759 ... -0.00473022  0.
#   0.00320435]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.5336609  -0.5697937  -0.5960388  ...  0.02703857  0.01489258
#   0.01519775]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.00521851 -0.03378296 -0.03460693 ... -0.08206177 -0.07717896
#  -0.07525635]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_6_pred.wav
# Left channel waveform: [0.14575195 0.17208862 0.1828003  ... 0.20913696 0.21786499 0.20687866]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [0.17852783 0.22406006 0.25836182 ... 0.2000122  0.20635986 0.19903564]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.03213501 -0.05084229 -0.09439087 ... -0.1569519  -0.1701355
#  -0.19592285]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# ...
# Left channel waveform: [-0.00445557 -0.0703125  -0.13687134 ... -0.02862549 -0.02941895
#  -0.01513672]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.00646973 -0.03375244 -0.02276611 ...  0.01119995  0.00534058
#   0.0010376 ]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_9_pred.wav
# Left channel waveform: [-0.05667114 -0.05773926 -0.052948   ...  0.08758545  0.06582642
#   0.08511353]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 7.93457031e-04  5.76782227e-03  1.21154785e-02 ... -6.10351562e-05
#   6.10351562e-05 -3.05175781e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.01123047 -0.02069092 -0.02261353 ... -0.04006958 -0.03057861
#  -0.01803589]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [ 0.17202759  0.1423645   0.12756348 ... -0.01980591  0.00305176
#   0.01565552]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_9_pred.wav
# Left channel waveform: [0.01834106 0.01889038 0.02404785 ... 0.10928345 0.09292603 0.08377075]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 7.93457031e-04  5.76782227e-03  1.21154785e-02 ... -6.10351562e-05
#   6.10351562e-05 -3.05175781e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [ 0.17877197  0.18844604  0.20132446 ... -0.15563965 -0.15533447
#  -0.15484619]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.15478516 -0.1539917  -0.15264893 ... -0.23580933 -0.19668579
#  -0.1486206 ]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_8_pred.wav
# Left channel waveform: [ 0.01400757  0.0005188  -0.00854492 ...  0.05834961  0.03808594
#   0.02438354]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-0.00842285 -0.03292847 -0.0486145  ... -0.00219727 -0.0027771
#  -0.00192261]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.10855103 -0.12612915 -0.14517212 ...  0.17279053  0.15576172
#   0.16003418]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.02960205 -0.03674316 -0.04452515 ... -0.03640747 -0.02520752
#  -0.03662109]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [ 0.06381226  0.07147217  0.09255981 ... -0.1159668  -0.10806274
#  -0.10150146]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.05407715 -0.0866394  -0.11203003 ... -0.01049805  0.0032959
#   0.00314331]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [ 0.05383301  0.09701538  0.09417725 ... -0.36605835 -0.42977905
#  -0.48736572]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [ 0.02020264  0.02539062  0.03839111 ... -0.05206299 -0.02636719
#  -0.00860596]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.0375061  -0.04425049 -0.06289673 ...  0.07006836  0.04367065
#   0.02603149]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.05108643 -0.043396   -0.03384399 ...  0.00143433  0.0324707
#  -0.01373291]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.09768677 -0.09738159 -0.08926392 ... -0.27905273 -0.24182129
#  -0.19659424]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.02371216 -0.02484131 -0.0262146  ...  0.05136108  0.02401733
#  -0.01040649]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.04507446 -0.07226562 -0.07034302 ... -0.11895752 -0.11373901
#  -0.11068726]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_2_pred.wav
# Left channel waveform: [-0.5385742  -0.5774231  -0.60668945 ...  0.00405884 -0.00082397
#  -0.00827026]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-6.1035156e-05  3.0517578e-05  3.0517578e-05 ...  1.2207031e-04
#   0.0000000e+00  1.5258789e-04]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [0.00421143 0.01956177 0.04376221 ... 0.15097046 0.07635498 0.00799561]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_9_pred.wav
# Left channel waveform: [-0.07421875 -0.07086182 -0.06488037 ... -0.02175903 -0.02703857
#   0.00131226]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 7.93457031e-04  5.76782227e-03  1.21154785e-02 ... -6.10351562e-05
#   6.10351562e-05 -3.05175781e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_8_pred.wav
# Left channel waveform: [-0.00076294 -0.02612305 -0.04516602 ... -0.0791626  -0.08847046
#  -0.0838623 ]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [-0.00842285 -0.03292847 -0.0486145  ... -0.00219727 -0.0027771
#  -0.00192261]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.05426025 -0.11715698 -0.17440796 ... -0.06741333 -0.06314087
#  -0.05621338]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# data/medley_processed/V2/MidnightBlue_StarsAreScreaming/vox_true/vocals_1_pred.wav
# Left channel waveform: [-0.17327881 -0.1550293  -0.13961792 ... -0.07037354 -0.10571289
#  -0.04788208]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# Left channel waveform: [ 1.2207031e-04  3.0517578e-05 -1.2207031e-04 ...  3.0517578e-05
#   3.0517578e-05 -6.1035156e-05]
# Left coefficients shape: [(13782,), (13782,), (27563,), (55125,), (110250,), (220500,)]
# Tensor coefficients shape: (6, 220500, 2)
# tf.Tensor(
# [[[-1.05975382e-01 -1.01950854e-01]
#   [-1.05975382e-01 -1.01950854e-01]
#   [-1.05975382e-01 -1.01950854e-01]
#   ...
#   [-2.87823170e-01 -3.70859891e-01]
#   [-2.87823170e-01 -3.70859891e-01]
#   [-2.87823170e-01 -3.70859891e-01]]
#
#  [[-7.05531463e-02  1.66591294e-02]
#   [-7.05531463e-02  1.66591294e-02]
#   [-7.05531463e-02  1.66591294e-02]
#   ...
#   [ 3.85920185e-09 -2.96495273e-10]
#   [ 3.85920185e-09 -2.96495273e-10]
#   [ 3.85920185e-09 -2.96495273e-10]]
#
#  [[-1.50375431e-02  7.09533459e-04]
#   [-1.50375431e-02  7.09533459e-04]
#   [-1.50375431e-02  7.09533459e-04]
#   ...
#   [ 7.54257989e-10  4.69765826e-09]
#   [ 7.54257989e-10  4.69765826e-09]
#   [ 7.54257989e-10  4.69765826e-09]]
#
#  [[-1.19117107e-02 -1.19332904e-02]
#   [-1.19117107e-02 -1.19332904e-02]
#   [-1.19117107e-02 -1.19332904e-02]
#   ...
#   [ 8.59283060e-02  7.65629560e-02]
#   [ 8.59283060e-02  7.65629560e-02]
#   [ 8.59283060e-02  7.65629560e-02]]
#
#  [[-9.59777739e-03  5.79834078e-03]
#   [-9.59777739e-03  5.79834078e-03]
#   [-4.42504184e-04  1.00708019e-03]
#   ...
#   [ 1.64031982e-02  1.21307364e-02]
#   [ 7.88879115e-03  2.33459845e-03]
#   [ 7.88879115e-03  2.33459845e-03]]
#
#  [[-9.06325877e-03 -5.33005875e-03]
#   [ 8.78272951e-03 -6.53849309e-03]
#   [-9.71063506e-03  9.04167909e-03]
#   ...
#   [ 1.92270558e-02 -1.76949275e-03]
#   [ 3.60372406e-03  2.87434757e-02]
#   [-9.96958558e-03 -7.57429749e-03]]], shape=(6, 220500, 2), dtype=float32)

# %%
train_tensor = tf.convert_to_tensor(y_train)
test_tensor = tf.convert_to_tensor(y_true)


# Convert TensorFlow tensors to NumPy arrays
train_array = train_tensor.numpy()
test_array = test_tensor.numpy()

# Save the NumPy arrays
np.save("y_train_level5.npy", train_array)
np.save("y_true_level5.npy", test_array)
